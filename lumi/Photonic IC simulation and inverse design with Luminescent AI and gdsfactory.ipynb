# %% [markdown]
# # Intro
#
# [Luminescent AI](https://luminescentai.com/) brings generative AI to photonics and RF. It empowers engineers to create complex optimal components just in a few lines of code! Specifically we created a GPU accelerated and automatic differentiation (AD) compatible FDTD package for simulation and inverse design of photonic integrated circuits (PIC), RF microstrip circuits, antennas and metasurfaces. Experimental release 🥼. Expect bugs 🐛🐞
#
# [Follow us](https://www.linkedin.com/company/luminescent-ai/about) for updates and bug fixes!

# %% [markdown]
# # Links
# [GitHub](https://github.com/paulxshen/Luminescent.jl): Star us :) We respond to issues within a day
# [LinkedIn](https://www.linkedin.com/company/luminescent-ai/about): Follow us for new features and bug fixes
# [Youtube](https://www.youtube.com/playlist?list=PLaK09N11V08geHeqyLJLDAW0tiDeJtnd4): Video tutorials
# [Company](luminescentai.com): Consulting, collaboration, funding, publication opportunities available
# [White Paper](https://docs.google.com/document/d/1b1kfDdRHw95AsR8zhrZYsHfCHLnULIO7uOYu8PxKQTM/edit?usp=sharing): Generative AI Cells for Semiconductor Photonics Design
# Email: pxshen@alumni.stanford.edu info@luminescentai.com
# WhatsApp: 650-776-7724
# WeChat: pxshen1230 懂中文

# %% [markdown]
# # Installation
# ## Windows
# ## Linux
# Please request

# %% [markdown]
# # Generative AI inverse design
# We introduce GCells (generative cells), a natural evolution of PCells (parametric cells) in semiconductor design . Given a set of inverse design objectives, a GCell will generate optimal geometry using adjoint optimization while ensuring manufacturability by enforcing minimum feature lengths.
#
# In examples below, `gcells.mimo` (multi in multi out) is just a gdsfactory component with configurable waveguide ports, simple slab as pre-optimization geometry, and overlying rectangular design regions. Dimensions `l` along x and `w` along y. Ports are numbered incrementally: west (SW->NW) -> east (SE->NE) -> south (SW->SE) -> north (NW->NE). By default, they're spaced equally on a side. Example: `west=1, east=2` places port 1 on west, ports 2 & 3 on east. But can also individually specify their locations and widths. Example : `west=[1.0, 2.5], wwg_west=[0.5, 0.4]`.
#
# `lmin` is minimum length scale . No fill or void features smaller than `lmin`.
#
# `approx_2D=True` optimizes in 2.5D which is significantly faster than 3D. Examples done at low resolution and lax convergence for speed. For accuracy, the result must be finetuned in 3D at finer resolution, a feature that can be requested from Luminescent AI .

# %% [markdown]
# ## Generative cells PDK for passive devices

# %% [markdown]
# ### 1x2 splitter MMI (tutorial)
# 1.55um wavelength 1x2 splitter. Symmetric about y so only need to specify T21=1.0. Data saved to `name` folder inside working directory. We start 30 iteratiions of adjoint optimization.

# %%
from pprint import pprint
import luminescent as lumi

c = lumi.gcells.mimo(west=1, east=2, l=4.0, w=2.0, wwg=.5, name="1x2_splitter")
targets = {"tparams":{1.55: {"2,1": 0.5}}}

prob = lumi.gcell_problem(
    c, targets, 
    symmetries=[1], lmin=0.15, dx=0.05, 
    approx_2D=True, iters=30, save_memory=True) # set to True if running out of RAM
sol = lumi.solve(prob)
pprint(sol["tparams"])
# Out:
# 2024-09-14 19:57:44.738 | WARNING  | kfactory.conf:_validate_layout_cache:254 - 'cell_layout_cache' has been set to True. This might cause when as any cell names generated automatically are loaded from the layout instead of created. This could happen e.g. after reading a gds file into the layout.
#
#           using simulation folder C:\Users\pxshe\OneDrive\Desktop\Luminescent.jl\lumi\1x2_splitter
#           started julia process
#           compiling julia code...
#
# setting up simulation...
# using CPU backend.
# starting optimization... first iter will be slow due to adjoint compilation.
#
# (1) losses tparams: 0.026863962
# weighted total loss 0.026863962
# 215.256336 seconds (1.04 G allocations: 66.325 GiB, 3.45% gc time, 11.94% compilation time)
#
# (2) losses tparams: 0.49272665
# weighted total loss 0.49272665
# 218.473803 seconds (1.03 G allocations: 65.343 GiB, 5.01% gc time, 0.06% compilation time)
#
# (3) losses tparams: 0.48891023
# weighted total loss 0.48891023
# 236.684172 seconds (1.03 G allocations: 65.330 GiB, 6.38% gc time, 0.00% compilation time)
#
# (4) losses tparams: 0.4591736
# weighted total loss 0.4591736
# 241.259459 seconds (1.03 G allocations: 65.330 GiB, 5.57% gc time, 0.00% compilation time)
#
# (5) losses tparams: 0.3981758
# weighted total loss 0.3981758
# 232.417528 seconds (1.03 G allocations: 65.330 GiB, 6.71% gc time, 0.00% compilation time)
#
# (6) losses tparams: 0.3891664
# weighted total loss 0.3891664
# 230.580649 seconds (1.03 G allocations: 65.330 GiB, 6.43% gc time, 0.00% compilation time)
#
# (7) losses tparams: 0.3703183
# weighted total loss 0.3703183
# 255.758128 seconds (1.03 G allocations: 65.330 GiB, 7.68% gc time, 0.00% compilation time)
#
# (8) losses tparams: 0.36064222
# weighted total loss 0.36064222
# 248.082378 seconds (1.03 G allocations: 65.330 GiB, 6.71% gc time, 0.00% compilation time)
#
# (9) losses tparams: 0.36135775
# weighted total loss 0.36135775
# 250.889326 seconds (1.03 G allocations: 65.330 GiB, 7.08% gc time, 0.00% compilation time)
#
# (10) losses tparams: 0.3371405
# weighted total loss 0.3371405
# 255.590790 seconds (1.03 G allocations: 65.330 GiB, 7.61% gc time, 0.00% compilation time)
#
# saving checkpoint...
# All errors:
# ===========================================
# ArgumentError: Package PNGFiles [f57f5aa1-a3ce-4bc8-8ab9-96f992907883] is required but does not seem to be installed:
# - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# ===========================================
# ArgumentError: Package ImageMagick [6218d12a-5da1-5696-b52f-db25d2ecc6d1] is required but does not seem to be installed:
# - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# ===========================================
# ArgumentError: Package OpenCV [f878e3a2-a245-4720-8660-60795d644f2a] is required but does not seem to be installed:
# - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# ===========================================
# MethodError: no method matching save(::FileIO.Stream{FileIO.DataFormat{:PNG}, IOContext{IOStream}, Nothing}, ::Matrix{ColorTypes.Gray{Bool}})
#
# Closest candidates are:
# save(!Matched::FileIO.File{FileIO.DataFormat{:HTML}}, ::Any)
# @ FileIO C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\mimesave.jl:49
# save(!Matched::FileIO.File{FileIO.DataFormat{:EPS}}, ::Any)
# @ FileIO C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\mimesave.jl:39
# save(!Matched::FileIO.File{FileIO.DataFormat{:PDF}}, ::Any)
# @ FileIO C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\mimesave.jl:29
# ...
#
# ===========================================
# All errors:
# ===========================================
# ArgumentError: Package PNGFiles [f57f5aa1-a3ce-4bc8-8ab9-96f992907883] is required but does not seem to be installed:
# - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# ===========================================
# ArgumentError: Package ImageMagick [6218d12a-5da1-5696-b52f-db25d2ecc6d1] is required but does not seem to be installed:
# - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# ===========================================
# ArgumentError: Package OpenCV [f878e3a2-a245-4720-8660-60795d644f2a] is required but does not seem to be installed:
# - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# ===========================================
# ArgumentError: Package PNGFiles [f57f5aa1-a3ce-4bc8-8ab9-96f992907883] is required but does not seem to be installed:
# - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# Stacktrace:
# [1] _require(pkg::Base.PkgId, env::Nothing)
# @ Base .\loading.jl:1926
# [2] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# @ Base .\loading.jl:1812
# [3] #invoke_in_world#3
# @ .\essentials.jl:926 [inlined]
# [4] invoke_in_world
# @ .\essentials.jl:923 [inlined]
# [5] _require_prelocked
# @ .\loading.jl:1803 [inlined]
# [6] _require_prelocked
# @ .\loading.jl:1802 [inlined]
# [7] macro expansion
# @ .\lock.jl:267 [inlined]
# [8] require(uuidkey::Base.PkgId)
# @ Base .\loading.jl:1797
# [9] (::LazyModules.var"#2#3"{Base.PkgId})()
# @ LazyModules C:\Users\pxshe\.julia\packages\LazyModules\d9Be6\src\LazyModules.jl:56
# [10] lock(f::LazyModules.var"#2#3"{Base.PkgId}, l::ReentrantLock)
# @ Base .\lock.jl:229
# [11] checked_import
# @ C:\Users\pxshe\.julia\packages\LazyModules\d9Be6\src\LazyModules.jl:54 [inlined]
# [12] checked_import
# @ C:\Users\pxshe\.julia\packages\LazyModules\d9Be6\src\LazyModules.jl:65 [inlined]
# [13] getproperty
# @ C:\Users\pxshe\.julia\packages\LazyModules\d9Be6\src\LazyModules.jl:40 [inlined]
# [14] save(s::FileIO.Stream{FileIO.DataFormat{:PNG}, IOContext{IOStream}, Nothing}, image::Matrix{ColorTypes.Gray{Bool}}; permute_horizontal::Bool, mapi::Function, kwargs::@Kwargs{})
# @ ImageIO C:\Users\pxshe\.julia\packages\ImageIO\eR22t\src\ImageIO.jl:79
# [15] save(s::FileIO.Stream{FileIO.DataFormat{:PNG}, IOContext{IOStream}, Nothing}, image::Matrix{ColorTypes.Gray{Bool}})
# @ ImageIO C:\Users\pxshe\.julia\packages\ImageIO\eR22t\src\ImageIO.jl:73
# [16] #invokelatest#2
# @ .\essentials.jl:892 [inlined]
# [17] invokelatest
# @ .\essentials.jl:889 [inlined]
# [18] action(call::Symbol, libraries::Vector{Union{Base.PkgId, Module}}, file::FileIO.Formatted, args::Matrix{ColorTypes.Gray{Bool}}; options::@Kwargs{})
# @ FileIO C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:219
# [19] action
# @ C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:196 [inlined]
# [20] #save#21
# @ C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:135 [inlined]
# [21] save
# @ C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:131 [inlined]
# [22] show(io::IOContext{IOStream}, mime::MIME{Symbol("image/png")}, img::Matrix{ColorTypes.Gray{Bool}}; minpixels::Int64, maxpixels::Int64, mapi::Function)
# @ ImageShow C:\Users\pxshe\.julia\packages\ImageShow\0sIWE\src\showmime.jl:49
# [23] show(io::IOContext{IOStream}, mime::MIME{Symbol("image/png")}, img::Matrix{ColorTypes.Gray{Bool}})
# @ ImageShow C:\Users\pxshe\.julia\packages\ImageShow\0sIWE\src\showmime.jl:29
# [24] show(io::IOContext{IOStream}, m::String, x::Matrix{ColorTypes.Gray{Bool}})
# @ Base.Multimedia .\multimedia.jl:123
# [25] #2
# @ C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\mimesave.jl:9 [inlined]
# [26] open(::FileIO.MimeWriter.var"#2#3"{Nothing, Matrix{ColorTypes.Gray{Bool}}}, ::String, ::Vararg{String}; kwargs::@Kwargs{})
# @ Base .\io.jl:396
# [27] open
# @ .\io.jl:393 [inlined]
# [28] save(file::FileIO.File{FileIO.DataFormat{:PNG}, String}, data::Matrix{ColorTypes.Gray{Bool}}; ppi::Nothing)
# @ FileIO.MimeWriter C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\mimesave.jl:7
# [29] save(file::FileIO.File{FileIO.DataFormat{:PNG}, String}, data::Matrix{ColorTypes.Gray{Bool}})
# @ FileIO.MimeWriter C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\mimesave.jl:5
# [30] #invokelatest#2
# @ .\essentials.jl:892 [inlined]
# [31] invokelatest
# @ .\essentials.jl:889 [inlined]
# [32] action(call::Symbol, libraries::Vector{Union{Base.PkgId, Module}}, file::FileIO.Formatted, args::Matrix{ColorTypes.Gray{Bool}}; options::@Kwargs{})
# @ FileIO C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:219
# [33] action
# @ C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:196 [inlined]
# [34] action
# @ C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:185 [inlined]
# [35] save(file::String, args::Matrix{ColorTypes.Gray{Bool}}; options::@Kwargs{})
# @ FileIO C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:129
# [36] save(file::String, args::Matrix{ColorTypes.Gray{Bool}})
# @ FileIO C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:125
# [37] gfrun(path::String; kw::@Kwargs{})
# @ Luminescent C:\Users\pxshe\OneDrive\Desktop\Luminescent.jl\src\gf.jl:592
# [38] gfrun
# @ C:\Users\pxshe\OneDrive\Desktop\Luminescent.jl\src\gf.jl:174 [inlined]
# [39] julia_main()
# @ Luminescent C:\Users\pxshe\OneDrive\Desktop\Luminescent.jl\src\gf.jl:12
# [40] top-level scope
# @ none:1
# ===========================================
# ┌ Warning: Package cuDNN not found in current path.
# │ - Run `import Pkg; Pkg.add("cuDNN")` to install the cuDNN package, then restart julia.
# │ - If cuDNN is not installed, some Flux functionalities will not be available when running on the GPU.
# └ @ FluxCUDAExt C:\Users\pxshe\.julia\packages\Flux\HBF2N\ext\FluxCUDAExt\FluxCUDAExt.jl:57
# Errors encountered while save FileIO.Stream{FileIO.DataFormat{:PNG}, IOContext{IOStream}, Nothing}(IOContext(IOStream(<file C:\Users\pxshe\OneDrive\Desktop\Luminescent.jl\lumi\1x2_splitter\checkpoints\2024-09-14T20_37_59_163\optimized_design_region_1.png>)), nothing).
#
# Fatal error:
# Errors encountered while save FileIO.File{FileIO.DataFormat{:PNG}, String}("C:\\Users\\pxshe\\OneDrive\\Desktop\\Luminescent.jl\\lumi\\1x2_splitter\\checkpoints\\2024-09-14T20_37_59_163\\optimized_design_region_1.png").
#
# Fatal error:
# ArgumentError: Package PNGFiles [f57f5aa1-a3ce-4bc8-8ab9-96f992907883] is required but does not seem to be installed:
#  - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# Stacktrace:
#   [1] _require(pkg::Base.PkgId, env::Nothing)
#     @ Base .\loading.jl:1926
#   [2] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
#     @ Base .\loading.jl:1812
#   [3] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#   [4] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#   [5] _require_prelocked
#     @ .\loading.jl:1803 [inlined]
#   [6] _require_prelocked
#     @ .\loading.jl:1802 [inlined]
#   [7] macro expansion
#     @ .\lock.jl:267 [inlined]
#   [8] require(uuidkey::Base.PkgId)
#     @ Base .\loading.jl:1797
#   [9] (::LazyModules.var"#2#3"{Base.PkgId})()
#     @ LazyModules C:\Users\pxshe\.julia\packages\LazyModules\d9Be6\src\LazyModules.jl:56
#  [10] lock(f::LazyModules.var"#2#3"{Base.PkgId}, l::ReentrantLock)
#     @ Base .\lock.jl:229
#  [11] checked_import
#     @ C:\Users\pxshe\.julia\packages\LazyModules\d9Be6\src\LazyModules.jl:54 [inlined]
#  [12] checked_import
#     @ C:\Users\pxshe\.julia\packages\LazyModules\d9Be6\src\LazyModules.jl:65 [inlined]
#  [13] getproperty
#     @ C:\Users\pxshe\.julia\packages\LazyModules\d9Be6\src\LazyModules.jl:40 [inlined]
#  [14] save(f::FileIO.File{FileIO.DataFormat{:PNG}, String}, image::Matrix{ColorTypes.Gray{Bool}}; kwargs::@Kwargs{})
#     @ ImageIO C:\Users\pxshe\.julia\packages\ImageIO\eR22t\src\ImageIO.jl:70
#  [15] save(f::FileIO.File{FileIO.DataFormat{:PNG}, String}, image::Matrix{ColorTypes.Gray{Bool}})
#     @ ImageIO C:\Users\pxshe\.julia\packages\ImageIO\eR22t\src\ImageIO.jl:69
#  [16] #invokelatest#2
#     @ .\essentials.jl:892 [inlined]
#  [17] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [18] action(call::Symbol, libraries::Vector{Union{Base.PkgId, Module}}, file::FileIO.Formatted, args::Matrix{ColorTypes.Gray{Bool}}; options::@Kwargs{})
#     @ FileIO C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:219
#  [19] action
#     @ C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:196 [inlined]
#  [20] action
#     @ C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:185 [inlined]
#  [21] save(file::String, args::Matrix{ColorTypes.Gray{Bool}}; options::@Kwargs{})
#     @ FileIO C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:129
#  [22] save(file::String, args::Matrix{ColorTypes.Gray{Bool}})
#     @ FileIO C:\Users\pxshe\.julia\packages\FileIO\xOKyx\src\loadsave.jl:125
#  [23] gfrun(path::String; kw::@Kwargs{})
#     @ Luminescent C:\Users\pxshe\OneDrive\Desktop\Luminescent.jl\src\gf.jl:592
#  [24] gfrun
#     @ C:\Users\pxshe\OneDrive\Desktop\Luminescent.jl\src\gf.jl:174 [inlined]
#  [25] julia_main()
#     @ Luminescent C:\Users\pxshe\OneDrive\Desktop\Luminescent.jl\src\gf.jl:12
#  [26] top-level scope
#     @ none:1
#
# images and results saved in C:\Users\pxshe\OneDrive\Desktop\Luminescent.jl\lumi\1x2_splitter
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       5 targets = {"tparams":{1.55: {"2,1": 0.5}}}
#       7 prob = lumi.gcell_problem(
#       8     c, targets,
#       9     symmetries=[1], lmin=0.15, dx=0.05,
#      10     approx_2D=True, iters=30, save_memory=True) # set to True if running out of RAM
# ---> 11 sol = lumi.solve(prob)
#      12 pprint(sol["tparams"])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\luminescent\gplugins\luminescent\sol.py:72, in solve(prob, dev, run)
#      64 # with Popen(cmd,  stdout=PIPE, stderr=PIPE) as p:
#      65 #     if p.stderr is not None:
#      66 #         for line in p.stderr:
#    (...)
#      69 # subprocess.run()
#      70 # print(f"julia simulation took {time.time()-start_time} seconds")
#      71 print(f"images and results saved in {path}")
# ---> 72 sol = load_solution(path=path)
#      73 if prob["study"] == "inverse_design":
#      74     c = apply_design(sol["component"],  sol)
#
# TypeError: load_solution() got an unexpected keyword argument 'path'

# %% [markdown]
# Can optimize more. `finetune` acts on latest modified design run folder if `name` not specified. Same for `show_solution` and `load_solution`

# %%
finetune(iters=10)
show_solution()

# %% [markdown]
# Can get optimized gdsfactory component, also saved as `optimized_component.gds` in run folder. Can also find `design_region_1.gds` and `design_region_1.png` for just the optimized design regions.

# %%
sol=load_solution()
c_opt=sol["optimized_component"]
c.plot()

# %% [markdown]
# ### 1x4 splitter MMI
# Need same phase on outputs. Because of symmetry, only need 0.0 phase difference between first 2 outputs.

# %%
from pprint import pprint
import luminescent as lumi

c = lumi.gcells.mimo(west=1, east=4, l=4.0, w=4.0, wwg=.5, name="1x4_splitter")
targets = {
    "tparams":{1.55: {"2,1": 0.25, "3,1":0.25}},
    "phasediff":{1.55: {"2,3": 0.0}},
    }

prob = lumi.gcell_problem(
    c, targets, 
    symmetries=[1], lmin=0.1, dx=0.05, 
    approx_2D=True, iters=40, save_memory=True) # set to True if running out of RAM
sol = lumi.solve(prob)

lumi.show_solution()

# %% [markdown]
# ### wavelength domain demultiplexer

# %%
from pprint import pprint
import luminescent as lumi

c = lumi.gcells.mimo(west=1, east=3, l=6.0, w=6.0, wwg=.5, name="demux")
targets = {"tparams":{
    1.55: {"2,1": 1.0},
    1.31: {"3,1": 1.0},
    1.10: {"4,1": 1.0},
}}

prob = lumi.gcell_problem(
    c, targets,
    lmin=0.1, dx=0.05, 
    approx_2D=True, iters=60, save_memory=True)
sol = lumi.solve(prob)

lumi.show_solution()

# %% [markdown]
# ### mode converter
# "o2@1,o1@0" means converting optical port 1 mode 0 to optical port 2 mode 1.

# %%
from pprint import pprint
import luminescent as lumi

c = lumi.gcells.mimo(west=1, east=1, l=3.0, w=3.0, wwg=.5, name="mode_converter")
targets = {"tparams":{1.55: {"o2@1,o1@0": 1.0}}}

prob = lumi.gcell_problem(
    c, targets,
    lmin=0.1, dx=0.05, 
    approx_2D=True, iters=40, save_memory=True)
sol = lumi.solve(prob)

lumi.show_solution()

# %% [markdown]
# ### symmetric crossing

# %%
from pprint import pprint
import luminescent as lumi

c = lumi.gcells.mimo(west=1, east=1, south=1, north=1, l=4.0, w=4.0, wwg=.5, name="crossing")
targets = {"tparams":{1.55: {"2,1": 1.0}}}

prob = lumi.gcell_problem(
    c, targets,
    lmin=0.1, dx=0.05, symmetries=[0,"diag"],
    approx_2D=True, iters=40, save_memory=True)
sol = lumi.solve(prob)

lumi.show_solution()
